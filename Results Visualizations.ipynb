# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
kNN = pd.read_csv("kNN results.csv")
kNN
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 5, 'knn__weights': 'dis...  0.958869
# 1   Waist  {'smote__k_neighbors': 5, 'knn__weights': 'dis...  0.947917
# 2   Wrist  {'smote__k_neighbors': 10, 'knn__weights': 'di...  0.926431
#
#    precision    recall        f1       contingency matrix
# 0   0.960498  0.958869  0.959228  [[258  12]\n [  4 115]]
# 1   0.955700  0.947917  0.949466  [[208  14]\n [  1  65]]
# 2   0.938765  0.926431  0.929494  [[272  23]\n [  4  68]]

# %%
kNN.at[0,"contingency matrix"] = np.array([[258, 12], [4, 115]])
kNN.at[1,"contingency matrix"] = np.array([[208, 14], [1, 65]])
kNN.at[2,"contingency matrix"] = np.array([[272, 23], [4, 68]])
kNN
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 5, 'knn__weights': 'dis...  0.958869
# 1   Waist  {'smote__k_neighbors': 5, 'knn__weights': 'dis...  0.947917
# 2   Wrist  {'smote__k_neighbors': 10, 'knn__weights': 'di...  0.926431
#
#    precision    recall        f1     contingency matrix
# 0   0.960498  0.958869  0.959228  [[258, 12], [4, 115]]
# 1   0.955700  0.947917  0.949466   [[208, 14], [1, 65]]
# 2   0.938765  0.926431  0.929494   [[272, 23], [4, 68]]

# %%
RF = pd.read_csv("RF results.csv")
RF
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 4, 'rf__n_estimators': ...  0.961440
# 1   Waist  {'smote__k_neighbors': 3, 'rf__n_estimators': ...  0.972222
# 2   Wrist  {'smote__k_neighbors': 3, 'rf__n_estimators': ...  0.956403
#
#    precision    recall        f1       contingency matrix
# 0   0.961363  0.961440  0.961394  [[263   7]\n [  8 111]]
# 1   0.972638  0.972222  0.972367  [[217   5]\n [  3  63]]
# 2   0.957613  0.956403  0.956844  [[285  10]\n [  6  66]]

# %%
RF.at[0,"contingency matrix"] = np.array([[263, 7], [8, 111]])
RF.at[1,"contingency matrix"] = np.array([[217, 5], [3, 63]])
RF.at[2,"contingency matrix"] = np.array([[285, 10], [6, 66]])
RF
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 4, 'rf__n_estimators': ...  0.961440
# 1   Waist  {'smote__k_neighbors': 3, 'rf__n_estimators': ...  0.972222
# 2   Wrist  {'smote__k_neighbors': 3, 'rf__n_estimators': ...  0.956403
#
#    precision    recall        f1    contingency matrix
# 0   0.961363  0.961440  0.961394  [[263, 7], [8, 111]]
# 1   0.972638  0.972222  0.972367   [[217, 5], [3, 63]]
# 2   0.957613  0.956403  0.956844  [[285, 10], [6, 66]]

# %%
GB = pd.read_csv("GB results.csv")
GB
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 4, 'gb__n_estimators': ...  0.976864
# 1   Waist  {'smote__k_neighbors': 10, 'gb__n_estimators':...  0.986111
# 2   Wrist  {'smote__k_neighbors': 3, 'gb__n_estimators': ...  0.959128
#
#    precision    recall        f1       contingency matrix
# 0   0.977156  0.976864  0.976943  [[264   6]\n [  3 116]]
# 1   0.986386  0.986111  0.986183  [[219   3]\n [  1  65]]
# 2   0.958933  0.959128  0.959020  [[288   7]\n [  8  64]]

# %%
GB.at[0,"contingency matrix"] = np.array([[264, 6], [3, 116]])
GB.at[1,"contingency matrix"] = np.array([[219, 3], [1, 65]])
GB.at[2,"contingency matrix"] = np.array([[288, 7], [8, 64]])
GB
# Out:
#   dataset                                    best parameters  accuracy  \
# 0    Neck  {'smote__k_neighbors': 4, 'gb__n_estimators': ...  0.976864
# 1   Waist  {'smote__k_neighbors': 10, 'gb__n_estimators':...  0.986111
# 2   Wrist  {'smote__k_neighbors': 3, 'gb__n_estimators': ...  0.959128
#
#    precision    recall        f1    contingency matrix
# 0   0.977156  0.976864  0.976943  [[264, 6], [3, 116]]
# 1   0.986386  0.986111  0.986183   [[219, 3], [1, 65]]
# 2   0.958933  0.959128  0.959020   [[288, 7], [8, 64]]

# %%
fig, axes = plt.subplots(3, 3, figsize = (20, 18))
ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9 = axes.flatten()
fig.tight_layout(pad=10)

#ax1 = [1, 1]
sns.heatmap(kNN["contingency matrix"][0], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax1)
ax1.set_ylabel("True", fontsize=15)
ax1.set_yticklabels(ax1.get_ymajorticklabels(), fontsize=15)
ax1.set_xlabel("Predicted", fontsize=15)
ax1.set_xticklabels(ax1.get_xmajorticklabels(), fontsize=15)
ax1.set_title("Neck - k Nearest Neighbors Classifier", fontsize=15)
#ax2 = [1, 2]
sns.heatmap(kNN["contingency matrix"][1], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax2)
ax2.set_ylabel("True", fontsize=15)
ax2.set_yticklabels(ax2.get_ymajorticklabels(), fontsize=15)
ax2.set_xlabel("Predicted", fontsize=15)
ax2.set_xticklabels(ax2.get_xmajorticklabels(), fontsize=15)
ax2.set_title("Waist - k Nearest Neighbors Classifier", fontsize=15)
#ax3 = [1, 3]
sns.heatmap(kNN["contingency matrix"][2], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax3)
ax3.set_ylabel("True", fontsize=15)
ax3.set_yticklabels(ax3.get_ymajorticklabels(), fontsize=15)
ax3.set_xlabel("Predicted", fontsize=15)
ax3.set_xticklabels(ax3.get_xmajorticklabels(), fontsize=15)
ax3.set_title("Wrist - k Nearest Neighbors Classifier",fontsize=15)

#ax4 = [2, 1]
sns.heatmap(RF["contingency matrix"][0], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax4)
ax4.set_ylabel("True", fontsize=15)
ax4.set_yticklabels(ax4.get_ymajorticklabels(), fontsize=15)
ax4.set_xlabel("Predicted", fontsize=15)
ax4.set_xticklabels(ax4.get_xmajorticklabels(), fontsize=15)
ax4.set_title("Neck - Random Forest Classifier", fontsize=15)
#ax5 = [2, 2]
sns.heatmap(RF["contingency matrix"][1], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax5)
ax5.set_ylabel("True", fontsize=15)
ax5.set_yticklabels(ax5.get_ymajorticklabels(), fontsize=15)
ax5.set_xlabel("Predicted", fontsize=15)
ax5.set_xticklabels(ax5.get_xmajorticklabels(), fontsize=15)
ax5.set_title("Waist - Random Forest Classifier", fontsize=15)
#ax6 = [2, 3]
sns.heatmap(RF["contingency matrix"][2], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax6)
ax6.set_ylabel("True", fontsize=15)
ax6.set_yticklabels(ax6.get_ymajorticklabels(), fontsize=15)
ax6.set_xlabel("Predicted", fontsize=15)
ax6.set_xticklabels(ax6.get_xmajorticklabels(), fontsize=15)
ax6.set_title("Wrist - Random Forest Classifier", fontsize=15)

#ax7 = [3, 1]
sns.heatmap(GB["contingency matrix"][0], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax7)
ax7.set_ylabel("True", fontsize=15)
ax7.set_yticklabels(ax7.get_ymajorticklabels(), fontsize=15)
ax7.set_xlabel("Predicted", fontsize=15)
ax7.set_xticklabels(ax7.get_xmajorticklabels(), fontsize=15)
ax7.set_title("Neck - Gradient Boost Classifier", fontsize=15)
#ax8 = [3, 2]
sns.heatmap(GB["contingency matrix"][1], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax8)
ax8.set_ylabel("True", fontsize=15)
ax8.set_yticklabels(ax8.get_ymajorticklabels(), fontsize=15)
ax8.set_xlabel("Predicted", fontsize=15)
ax8.set_xticklabels(ax8.get_xmajorticklabels(), fontsize=15)
ax8.set_title("Waist - Gradient Boost Classifier", fontsize=15)
#ax9 = [3, 3]
sns.heatmap(GB["contingency matrix"][2], annot=True, annot_kws={"fontsize":15}, fmt=".0f", cmap='Blues', cbar=False, vmin=0, vmax=300, ax=ax9)
ax9.set_ylabel("True", fontsize=15)
ax9.set_yticklabels(ax9.get_ymajorticklabels(), fontsize=15)
ax9.set_xlabel("Predicted", fontsize=15)
ax9.set_xticklabels(ax9.get_xmajorticklabels(), fontsize=15)
ax9.set_title("Wrist - Gradient Boost Classifier", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Wrist - Gradient Boost Classifier')
